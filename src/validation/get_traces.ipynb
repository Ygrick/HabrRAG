# %%
import mlflow
from mlflow.tracking import MlflowClient
import pandas as pd
import json

# %%
# 1. Настройки (должны совпадать с вашим скриптом валидации)
MLFLOW_URI = "http://127.0.0.1:5001"
TARGET_RUN_ID = "8f29da97ce2f4612a8b14cf7bccaf648"  # Вставьте сюда ID из вывода валидации
EXPERIMENT_ID = "3"

# Инициализация клиента
mlflow.set_tracking_uri(MLFLOW_URI)
client = MlflowClient(tracking_uri=MLFLOW_URI)

# %%
def get_run_details(run_id):
    """Получает базовые метрики и параметры Run-а."""
    run = client.get_run(run_id)
    print(f"--- Run: {run_id} ---")
    print(f"Status: {run.info.status}")
    print(f"Params: {json.dumps(run.data.params, indent=2)}")
    print(f"Metrics: {json.dumps(run.data.metrics, indent=2)}")
    return run

def get_llm_traces(run_id, experiment_id):
    """Извлекает LLM трейсы (входы, выходы, промежуточные шаги)."""
    # search_traces возвращает список объектов Trace
    traces = client.search_traces(
        experiment_ids=[experiment_id], # Можно оставить пустым, если фильтруем по run_id
        filter_string=f"attributes.run_id = '{run_id}'"
    )
    extracted_data = []
    print(f"\n--- Найдено трейсов: {len(traces)} ---")
    
    for trace in traces:
        # Каждый trace содержит data (spans) и info
        # Обычно корневой span (первый) содержит общий вход и выход RAG
        root_span = trace.data.spans[0]
        trace_info = {
            "request_id": trace.info.request_id,
            "timestamp": trace.info.timestamp_ms,
            "latency_ms": trace.info.execution_time_ms,
            "status": trace.info.status,
            # Входы и выходы могут быть строками или JSON
            "input": root_span.inputs, 
            "output": root_span.outputs,
        }
        
        # Если нужно углубиться в детали (например, retrieved documents)
        # нужно перебирать spans внутри trace.data.spans
        # Пример поиска span с именем "Retriever" (название зависит от вашей реализации)
        retriever_span = next((s for s in trace.data.spans if "retriev" in s.name.lower()), None)
        if retriever_span:
            trace_info["retrieved_docs"] = retriever_span.outputs
        extracted_data.append(trace_info)
    return extracted_data

# %%
# 1. Получаем общую информацию
run = get_run_details(TARGET_RUN_ID)
run
# Out:
# --- Run: 8f29da97ce2f4612a8b14cf7bccaf648 ---
# Status: FINISHED
# Params: {
#   "validation_timestamp": "2025-12-09T18:03:29.337680",
#   "run_type": "validation"
# }
# Metrics: {}
# <Run: data=<RunData: metrics={}, params={'run_type': 'validation', 'validation_timestamp': '2025-12-09T18:03:29.337680'}, tags={'mlflow.runName': 'validation_20251209_180328',
#  'mlflow.source.git.commit': 'cf2f4469651cb71f1691cfa96b1d6d03c49c1174',
#  'mlflow.source.name': 'src/validation/run.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'i.romaikin'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/8f29da97ce2f4612a8b14cf7bccaf648/artifacts', end_time=1765292672435, experiment_id='3', lifecycle_stage='active', run_id='8f29da97ce2f4612a8b14cf7bccaf648', run_name='validation_20251209_180328', start_time=1765292609315, status='FINISHED', user_id='i.romaikin'>, inputs=<RunInputs: dataset_inputs=[], model_inputs=[]>, outputs=<RunOutputs: model_outputs=[]>>

# %%
# 2. Получаем контент трейсов
traces_content = get_llm_traces(TARGET_RUN_ID, EXPERIMENT_ID)
traces_content
# Out:
# --- Найдено трейсов: 4 ---
# [{'request_id': 'tr-b660fb9af941f0e1789c7d0e596cc36f',
#   'timestamp': 1765292655128,
#   'latency_ms': 17160,
#   'status': <TraceStatus.OK: 'OK'>,
#   'input': {'query': 'Как создать кастомную тень для View, чтобы она имела произвольную форму, учитывая ограничения свойства android:elevation?',
#    'documents': [],
#    'doc_ids': '',
#    'answer': ''},
#   'output': {'query': 'Как создать пользовательскую тень произвольной формы для View, учитывая ограничения свойства android:elevation?',
#    'documents': [{'id': 558542,
#      'author': 'mobileSimbirSoft',
#      'url': 'https://habr.com/ru/post/558542/',
#      'title': 'То, чего нам так не хватало: Render Effect в Android 12',
#      'document_id': 5,
#      'chunk_id': 6,
#      'content': 'REPEAT. Изображение повторяется горизонтально и вертикально. На изображении заметно, как темная вода из нижней части изображения отразилась на верхней границе изображения.\n DECAL (появился в API 31). Отрисовка shader-а только в пределах границ. Можно заметить, что на границе изображение стало чуть светлее.\nМы также можем применить размытие при создании тени. Конечно, можно просто создать тень с помощью свойства Elevation:\n[code]\n android:elevation="10dp"\n[/code]\nОднако, в этом случае мы не сможем задавать направление, в котором должна отбрасываться тень, или ее цвет. Также тень для Elevation по умолчанию работает только с формами скругленного прямоугольника (круг и прямоугольник – частные случаи прямоугольника со скругленными углами). Для тени другой формы нужно реализовать ViewOutlineProvider, чтобы он возвращал Outline с setPath(...), а это может быть весьма трудоемко.\nКастомную тень можно создать и с помощью xml, прописав с градиентом:\n[code]\n \n[/code]'},
#     {'id': 558542,
#      'author': 'mobileSimbirSoft',
#      'url': 'https://habr.com/ru/post/558542/',
#      'title': 'То, чего нам так не хватало: Render Effect в Android 12',
#      'document_id': 6,
#      'chunk_id': 7,
#      'content': 'Кастомную тень можно создать и с помощью xml, прописав с градиентом:\n[code]\n \n[/code]\nМы получили тень круглой формы, ложащуюся от белого круга одинаково во всех направлениях – то есть сверху она такой же длины, что и снизу. Но мы все же не сможем таким способом сделать тень сложной формы.\nСначала для сравнения покажем, как можно реализовать аналогичную тень круглой формы с помощью RenderEffect. Создаем круг серого цвета:\n[code]\n \n \n \n[/code]\nЗатем этот drawable устанавливаем в качестве содержимого ImageView и применяем размытие к ImageView:\n[code]\n imageView.setImageResource(R.drawable.gray_circle)\n val renderEffect = RenderEffect.createBlurEffect(20f, 20f, Shader.TileMode.CLAMP)\n imageView.setRenderEffect(renderEffect)\n[/code]\nА вот как с помощью RenderEffect можно добиться тени произвольной формы и, если понадобится, произвольного цвета:\n[code]\n \n[/code]\n[code]\n val effect = RenderEffect.createBlurEffect(10f, 10f, Shader.TileMode.CLAMP)'}],
#    'doc_ids': '{"relevant_documents":[{"document_id":558542,"chunk_id":6},{"document_id":558542,"chunk_id":7}]}',
#    'answer': '**Как создать пользовательскую тень произвольной формы для View**\n\n1. **Создайте графический ресурс нужной формы**  \n   - Если тень должна быть круглой, прямоугольной, многоугольной и т.д., нарисуйте соответствующий `Drawable` (например, `ShapeDrawable`, `VectorDrawable`, растровый PNG и т.п.).  \n   - В примере из статьи создаётся серый круг (`gray_circle`) – это и есть «корень» тени.\n\n2. **Примените к View нужный `RenderEffect`**  \n   ```kotlin\n   // 1. Подготовка изображения (или другого View)\n   imageView.setImageResource(R.drawable.gray_circle)   // или imageView.background = ...\n\n   // 2. Создание эффекта размытия\n   val renderEffect = RenderEffect.createBlurEffect(\n       10f, 10f,          // радиусы размытия по X и Y\n       Shader.TileMode.CLAMP // режим повторения (можно REPEAT, DECAL и др.)\n   )\n   imageView.setRenderEffect(renderEffect)   // применяем к View\n   ```\n   - `RenderEffect.createBlurEffect` позволяет задать произвольную форму (по графике, которую вы передали) и цвет тени (если вы отрисуете нужный цвет в drawable).\n\n3. **Для более сложных форм**  \n   - Если вам нужно тень, которая не совпадает с контуром View, можно использовать `RenderEffect` вместе с кастомным `OutlineProvider`.  \n   - Создайте `ViewOutlineProvider`, в котором `setPath(...)` задаёт нужный контур, и примените его к View.  \n   - Это «трудоемко», но позволяет полностью контролировать форму тени, как отмечено в документе.\n\n4. **Преимущества по сравнению с `android:elevation`**  \n   - `elevation` создаёт тень только для скруглённых прямоугольников и не позволяет задать направление, цвет или произвольную форму.  \n   - С `RenderEffect` вы можете задать любую форму, направление (через смещение в `BlurEffect`), цвет и степень размытия.\n\n**Итог**  \nДля создания пользовательской тени произвольной формы используйте `RenderEffect.createBlurEffect` и применяйте его к нужному `View` (или `ImageView`). Если форма должна отличаться от границ View, дополнительно задайте `OutlineProvider` с нужным контуром. Это позволит обойти ограничения `android:elevation`.  \n\n*Источник: [Document ID 558542]*'},
#   'retrieved_docs': {'query': 'Как создать пользовательскую тень произвольной формы для View, учитывая ограничения свойства android:elevation?',
#    'documents': [{'id': 558542,
#      'author': 'mobileSimbirSoft',
#      'url': 'https://habr.com/ru/post/558542/',
#      'title': 'То, чего нам так не хватало: Render Effect в Android 12',
#      'document_id': 5,
#      'chunk_id': 6,
#      'content': 'REPEAT. Изображение повторяется горизонтально и вертикально. На изображении заметно, как темная вода из нижней части изображения отразилась на верхней границе изображения.\n DECAL (появился в API 31). Отрисовка shader-а только в пределах границ. Можно заметить, что на границе изображение стало чуть светлее.\nМы также можем применить размытие при создании тени. Конечно, можно просто создать тень с помощью свойства Elevation:\n[code]\n android:elevation="10dp"\n[/code]\nОднако, в этом случае мы не сможем задавать направление, в котором должна отбрасываться тень, или ее цвет. Также тень для Elevation по умолчанию работает только с формами скругленного прямоугольника (круг и прямоугольник – частные случаи прямоугольника со скругленными углами). Для тени другой формы нужно реализовать ViewOutlineProvider, чтобы он возвращал Outline с setPath(...), а это может быть весьма трудоемко.\nКастомную тень можно создать и с помощью xml, прописав с градиентом:\n[code]\n \n[/code]'},
#     {'id': 558542,
#      'author': 'mobileSimbirSoft',
#      'url': 'https://habr.com/ru/post/558542/',
#      'title': 'То, чего нам так не хватало: Render Effect в Android 12',
#      'document_id': 6,
#      'chunk_id': 7,
#      'content': 'Кастомную тень можно создать и с помощью xml, прописав с градиентом:\n[code]\n \n[/code]\nМы получили тень круглой формы, ложащуюся от белого круга одинаково во всех направлениях – то есть сверху она такой же длины, что и снизу. Но мы все же не сможем таким способом сделать тень сложной формы.\nСначала для сравнения покажем, как можно реализовать аналогичную тень круглой формы с помощью RenderEffect. Создаем круг серого цвета:\n[code]\n \n \n \n[/code]\nЗатем этот drawable устанавливаем в качестве содержимого ImageView и применяем размытие к ImageView:\n[code]\n imageView.setImageResource(R.drawable.gray_circle)\n val renderEffect = RenderEffect.createBlurEffect(20f, 20f, Shader.TileMode.CLAMP)\n imageView.setRenderEffect(renderEffect)\n[/code]\nА вот как с помощью RenderEffect можно добиться тени произвольной формы и, если понадобится, произвольного цвета:\n[code]\n \n[/code]\n[code]\n val effect = RenderEffect.createBlurEffect(10f, 10f, Shader.TileMode.CLAMP)'}],
#    'doc_ids': '',
#    'answer': ''}},
#  {'request_id': 'tr-71da94c6e7948a253982c5428825dae8',
#   'timestamp': 1765292643177,
#   'latency_ms': 11609,
#   'status': <TraceStatus.OK: 'OK'>,
#   'input': {'query': 'Какую новую форму оценки требуют абитуриенты Университета Чикаго с этой осени?',
#    'documents': [],
#    'doc_ids': '',
#    'answer': ''},
#   'output': {'query': 'Какая новая методика оценки требуется от абитуриентов Университета Чикаго к началу осеннего семестра?',
#    'documents': [{'id': 12730,
#      'author': 'Юлия Благовещенская (skazala)',
#      'url': 'https://habr.com/ru/post/12730/',
#      'title': 'Хочешь в университет — сделай презентацию',
#      'document_id': 1,
#      'chunk_id': 1,
#      'content': 'Абитуриенты, поступающие в Университет Чикаго, уже начиная с этой осени, будут обязаны, помимо сдачи основных экзаменов, представить четырехстраничные презентации в формате PowerPoint — на свободную тему.\nЧастично новые требования связаны с тем, что PowerPoint становится одним из бизнес-инструментов, а кроме того, считают авторы инициативы, в презентации абитуриент сможет раскрыть свои новые качества, которые не смогут проявиться на традиционных экзаменах.\nФормат PowerPoint стал своего рода языком делового общения. Ежедневно, по оценкам Microsoft, в мире показывается порядка 30 млн презентаций.\nvia AP'},
#     {'id': 598357,
#      'author': 'Никита Цаплин (ntsaplin)',
#      'url': 'https://habr.com/ru/post/598357/',
#      'title': 'Все врут-2: чем закончился детектив про медленные NVMe и невозможность делать RAID',
#      'document_id': 6,
#      'chunk_id': 29,
#      'content': 'Чтобы полностью исключить шину UPI из обработки и передачи данных, мы поступим самым простым и надёжным способом: отключим CPU2, а также все модули RAM и диски NVME, к нему относящиеся:\nНа фотографии видно, что слоты CPU2 и относящихся к нему RAM- и NVME-дисков не заняты. Дальше для тестирования используем diskspd. Тесты проводим под Windows Server 2016 и Windows Server 2019.\nТест чтения: DiskSpd64.exe -b4K -t32 -o32 -w0 -d10 -r -S -c100G F:/testfile.dat G:/testfile.dat\nТест записи: DiskSpd64.exe -b4K -t32 -o32 -w100 -d10 -r -S -c100G F:/testfile.dat G:/testfile.dat\nРезультаты:\nWrite (percent)\nWin2016 — IOPS\nWin2019 — IOPS\n0 (read)\n1132231.01\n1026432.57 (- 9 %)\n100 (write)\n863745.10\n953902.69 (+ 10 %)\nПод Win2019 чтение медленнее на 9 %, но зато на 10 % быстрее запись, чем под Win2016.\nВо всех тестах нагрузка CPU была 95–98 %. Отсюда возникает вопрос, как изменится скорость, если поставить второй CPU. Поставим второй CPU и проведём соответствующий тест.\nWindows Server 2016:'}],
#    'doc_ids': '{"relevant_documents":[{"document_id":1,"chunk_id":1}]}',
#    'answer': 'Новые требования к абитуриентам Университета Чикаго к началу осеннего семестра включают обязательный подачу **четырёхстраничной презентации в формате PowerPoint** (на свободную тему) в дополнение к сдаче основных экзаменов.  \n\n[1]'},
#   'retrieved_docs': {'query': 'Какая новая методика оценки требуется от абитуриентов Университета Чикаго к началу осеннего семестра?',
#    'documents': [{'id': 12730,
#      'author': 'Юлия Благовещенская (skazala)',
#      'url': 'https://habr.com/ru/post/12730/',
#      'title': 'Хочешь в университет — сделай презентацию',
#      'document_id': 1,
#      'chunk_id': 1,
#      'content': 'Абитуриенты, поступающие в Университет Чикаго, уже начиная с этой осени, будут обязаны, помимо сдачи основных экзаменов, представить четырехстраничные презентации в формате PowerPoint — на свободную тему.\nЧастично новые требования связаны с тем, что PowerPoint становится одним из бизнес-инструментов, а кроме того, считают авторы инициативы, в презентации абитуриент сможет раскрыть свои новые качества, которые не смогут проявиться на традиционных экзаменах.\nФормат PowerPoint стал своего рода языком делового общения. Ежедневно, по оценкам Microsoft, в мире показывается порядка 30 млн презентаций.\nvia AP'},
#     {'id': 598357,
#      'author': 'Никита Цаплин (ntsaplin)',
#      'url': 'https://habr.com/ru/post/598357/',
#      'title': 'Все врут-2: чем закончился детектив про медленные NVMe и невозможность делать RAID',
#      'document_id': 6,
#      'chunk_id': 29,
#      'content': 'Чтобы полностью исключить шину UPI из обработки и передачи данных, мы поступим самым простым и надёжным способом: отключим CPU2, а также все модули RAM и диски NVME, к нему относящиеся:\nНа фотографии видно, что слоты CPU2 и относящихся к нему RAM- и NVME-дисков не заняты. Дальше для тестирования используем diskspd. Тесты проводим под Windows Server 2016 и Windows Server 2019.\nТест чтения: DiskSpd64.exe -b4K -t32 -o32 -w0 -d10 -r -S -c100G F:/testfile.dat G:/testfile.dat\nТест записи: DiskSpd64.exe -b4K -t32 -o32 -w100 -d10 -r -S -c100G F:/testfile.dat G:/testfile.dat\nРезультаты:\nWrite (percent)\nWin2016 — IOPS\nWin2019 — IOPS\n0 (read)\n1132231.01\n1026432.57 (- 9 %)\n100 (write)\n863745.10\n953902.69 (+ 10 %)\nПод Win2019 чтение медленнее на 9 %, но зато на 10 % быстрее запись, чем под Win2016.\nВо всех тестах нагрузка CPU была 95–98 %. Отсюда возникает вопрос, как изменится скорость, если поставить второй CPU. Поставим второй CPU и проведём соответствующий тест.\nWindows Server 2016:'}],
#    'doc_ids': '',
#    'answer': ''}},
#  {'request_id': 'tr-b8854fdd3c08f65b6dde8f8bc508d352',
#   'timestamp': 1765292624930,
#   'latency_ms': 17756,
#   'status': <TraceStatus.OK: 'OK'>,
#   'input': {'query': 'Какие ограничения у свойства android:elevation при создании теней в Android, и как можно получить тень с заданным направлением и цветом?',
#    'documents': [],
#    'doc_ids': '',
#    'answer': ''},
#   'output': {'query': 'Каковы ограничения атрибута\u202fandroid:elevation при формировании теней в Android, и как можно задать тень с конкретным направлением и цветом?',
#    'documents': [{'id': 558542,
#      'author': 'mobileSimbirSoft',
#      'url': 'https://habr.com/ru/post/558542/',
#      'title': 'То, чего нам так не хватало: Render Effect в Android 12',
#      'document_id': 5,
#      'chunk_id': 6,
#      'content': 'REPEAT. Изображение повторяется горизонтально и вертикально. На изображении заметно, как темная вода из нижней части изображения отразилась на верхней границе изображения.\n DECAL (появился в API 31). Отрисовка shader-а только в пределах границ. Можно заметить, что на границе изображение стало чуть светлее.\nМы также можем применить размытие при создании тени. Конечно, можно просто создать тень с помощью свойства Elevation:\n[code]\n android:elevation="10dp"\n[/code]\nОднако, в этом случае мы не сможем задавать направление, в котором должна отбрасываться тень, или ее цвет. Также тень для Elevation по умолчанию работает только с формами скругленного прямоугольника (круг и прямоугольник – частные случаи прямоугольника со скругленными углами). Для тени другой формы нужно реализовать ViewOutlineProvider, чтобы он возвращал Outline с setPath(...), а это может быть весьма трудоемко.\nКастомную тень можно создать и с помощью xml, прописав с градиентом:\n[code]\n \n[/code]'},
#     {'id': 558542,
#      'author': 'mobileSimbirSoft',
#      'url': 'https://habr.com/ru/post/558542/',
#      'title': 'То, чего нам так не хватало: Render Effect в Android 12',
#      'document_id': 6,
#      'chunk_id': 7,
#      'content': 'Кастомную тень можно создать и с помощью xml, прописав с градиентом:\n[code]\n \n[/code]\nМы получили тень круглой формы, ложащуюся от белого круга одинаково во всех направлениях – то есть сверху она такой же длины, что и снизу. Но мы все же не сможем таким способом сделать тень сложной формы.\nСначала для сравнения покажем, как можно реализовать аналогичную тень круглой формы с помощью RenderEffect. Создаем круг серого цвета:\n[code]\n \n \n \n[/code]\nЗатем этот drawable устанавливаем в качестве содержимого ImageView и применяем размытие к ImageView:\n[code]\n imageView.setImageResource(R.drawable.gray_circle)\n val renderEffect = RenderEffect.createBlurEffect(20f, 20f, Shader.TileMode.CLAMP)\n imageView.setRenderEffect(renderEffect)\n[/code]\nА вот как с помощью RenderEffect можно добиться тени произвольной формы и, если понадобится, произвольного цвета:\n[code]\n \n[/code]\n[code]\n val effect = RenderEffect.createBlurEffect(10f, 10f, Shader.TileMode.CLAMP)'}],
#    'doc_ids': '{"relevant_documents":[{"document_id":558542,"chunk_id":6}]}',
#    'answer': ''},
#   'retrieved_docs': {'query': 'Каковы ограничения атрибута\u202fandroid:elevation при формировании теней в Android, и как можно задать тень с конкретным направлением и цветом?',
#    'documents': [{'id': 558542,
#      'author': 'mobileSimbirSoft',
#      'url': 'https://habr.com/ru/post/558542/',
#      'title': 'То, чего нам так не хватало: Render Effect в Android 12',
#      'document_id': 5,
#      'chunk_id': 6,
#      'content': 'REPEAT. Изображение повторяется горизонтально и вертикально. На изображении заметно, как темная вода из нижней части изображения отразилась на верхней границе изображения.\n DECAL (появился в API 31). Отрисовка shader-а только в пределах границ. Можно заметить, что на границе изображение стало чуть светлее.\nМы также можем применить размытие при создании тени. Конечно, можно просто создать тень с помощью свойства Elevation:\n[code]\n android:elevation="10dp"\n[/code]\nОднако, в этом случае мы не сможем задавать направление, в котором должна отбрасываться тень, или ее цвет. Также тень для Elevation по умолчанию работает только с формами скругленного прямоугольника (круг и прямоугольник – частные случаи прямоугольника со скругленными углами). Для тени другой формы нужно реализовать ViewOutlineProvider, чтобы он возвращал Outline с setPath(...), а это может быть весьма трудоемко.\nКастомную тень можно создать и с помощью xml, прописав с градиентом:\n[code]\n \n[/code]'},
#     {'id': 558542,
#      'author': 'mobileSimbirSoft',
#      'url': 'https://habr.com/ru/post/558542/',
#      'title': 'То, чего нам так не хватало: Render Effect в Android 12',
#      'document_id': 6,
#      'chunk_id': 7,
#      'content': 'Кастомную тень можно создать и с помощью xml, прописав с градиентом:\n[code]\n \n[/code]\nМы получили тень круглой формы, ложащуюся от белого круга одинаково во всех направлениях – то есть сверху она такой же длины, что и снизу. Но мы все же не сможем таким способом сделать тень сложной формы.\nСначала для сравнения покажем, как можно реализовать аналогичную тень круглой формы с помощью RenderEffect. Создаем круг серого цвета:\n[code]\n \n \n \n[/code]\nЗатем этот drawable устанавливаем в качестве содержимого ImageView и применяем размытие к ImageView:\n[code]\n imageView.setImageResource(R.drawable.gray_circle)\n val renderEffect = RenderEffect.createBlurEffect(20f, 20f, Shader.TileMode.CLAMP)\n imageView.setRenderEffect(renderEffect)\n[/code]\nА вот как с помощью RenderEffect можно добиться тени произвольной формы и, если понадобится, произвольного цвета:\n[code]\n \n[/code]\n[code]\n val effect = RenderEffect.createBlurEffect(10f, 10f, Shader.TileMode.CLAMP)'}],
#    'doc_ids': '',
#    'answer': ''}},
#  {'request_id': 'tr-b6b7066273722baa79262943f9d8a986',
#   'timestamp': 1765292610033,
#   'latency_ms': 14529,
#   'status': <TraceStatus.OK: 'OK'>,
#   'input': {'query': 'Сколько презентаций PowerPoint, по оценкам Microsoft, демонстрируется в мире ежедневно?',
#    'documents': [],
#    'doc_ids': '',
#    'answer': ''},
#   'output': {'query': 'Сколько презентаций PowerPoint ежедневно демонстрируется в мире согласно оценкам Microsoft?',
#    'documents': [{'id': 12730,
#      'author': 'Юлия Благовещенская (skazala)',
#      'url': 'https://habr.com/ru/post/12730/',
#      'title': 'Хочешь в университет — сделай презентацию',
#      'document_id': 1,
#      'chunk_id': 1,
#      'content': 'Абитуриенты, поступающие в Университет Чикаго, уже начиная с этой осени, будут обязаны, помимо сдачи основных экзаменов, представить четырехстраничные презентации в формате PowerPoint — на свободную тему.\nЧастично новые требования связаны с тем, что PowerPoint становится одним из бизнес-инструментов, а кроме того, считают авторы инициативы, в презентации абитуриент сможет раскрыть свои новые качества, которые не смогут проявиться на традиционных экзаменах.\nФормат PowerPoint стал своего рода языком делового общения. Ежедневно, по оценкам Microsoft, в мире показывается порядка 30 млн презентаций.\nvia AP'},
#     {'id': 598357,
#      'author': 'Никита Цаплин (ntsaplin)',
#      'url': 'https://habr.com/ru/post/598357/',
#      'title': 'Все врут-2: чем закончился детектив про медленные NVMe и невозможность делать RAID',
#      'document_id': 7,
#      'chunk_id': 30,
#      'content': 'Windows Server 2016:\nWrite (percent)\nодин CPU — IOPS\nдва CPU — IOPS\n0 (read)\n1132231.01\n590263.08 ( — 48 %)\n100 (write)\n863745.10\n594401.43 ( — 32 %)\nWindows Server 2019:\nWrite (percent)\nодин CPU — IOPS\nдва CPU — IOPS\n0 (read)\n1026432.57\n818586.28 ( — 21%)\n100 (write)\n953902.69\n842953.92 ( — 12 %)\nВидно, что синхронизация работы CPU через UPI-линию существенно снизила результаты. Падение производительности с двумя CPU под Win2019 существенно меньше, чем под Win2016.\n### ▍ Вторая часть марлезонского балета:\nА теперь установим оба CPU. Но вся RAM будет на CPU1, а NVME — на CPU2.\nRAM подключена к CPU1, а NVME-диски — к CPU2.\nТесты на количество IOPS такие же, как в предыдущем разделе.\nТесты на пропускную способность:\nЧтение: DiskSpd64.exe -b128K -t32 -o32 -w0 -d10 -si -S -c100G F:/testfile.dat G:/testfile.dat\nЗапись: DiskSpd64.exe -b128K -t32 -o32 -w100 -d10 -si -S -c100G F:/testfile.dat G:/testfile.dat\nКоличество IOPS:\nWrite (Percent)\nWin2016 — IOPS — 4K\nWin2019 — IOPS — 4K block'}],
#    'doc_ids': '```json\n{\n  "relevant_documents": [\n    {"document_id": 1, "chunk_id": 1}\n  ]\n}\n```',
#    'answer': 'По оценкам Microsoft ежедневно в мире демонстрируется примерно **30\u202fмлн презентаций PowerPoint**. [Document\u202f1]'},
#   'retrieved_docs': {'query': 'Сколько презентаций PowerPoint ежедневно демонстрируется в мире согласно оценкам Microsoft?',
#    'documents': [{'id': 12730,
#      'author': 'Юлия Благовещенская (skazala)',
#      'url': 'https://habr.com/ru/post/12730/',
#      'title': 'Хочешь в университет — сделай презентацию',
#      'document_id': 1,
#      'chunk_id': 1,
#      'content': 'Абитуриенты, поступающие в Университет Чикаго, уже начиная с этой осени, будут обязаны, помимо сдачи основных экзаменов, представить четырехстраничные презентации в формате PowerPoint — на свободную тему.\nЧастично новые требования связаны с тем, что PowerPoint становится одним из бизнес-инструментов, а кроме того, считают авторы инициативы, в презентации абитуриент сможет раскрыть свои новые качества, которые не смогут проявиться на традиционных экзаменах.\nФормат PowerPoint стал своего рода языком делового общения. Ежедневно, по оценкам Microsoft, в мире показывается порядка 30 млн презентаций.\nvia AP'},
#     {'id': 598357,
#      'author': 'Никита Цаплин (ntsaplin)',
#      'url': 'https://habr.com/ru/post/598357/',
#      'title': 'Все врут-2: чем закончился детектив про медленные NVMe и невозможность делать RAID',
#      'document_id': 7,
#      'chunk_id': 30,
#      'content': 'Windows Server 2016:\nWrite (percent)\nодин CPU — IOPS\nдва CPU — IOPS\n0 (read)\n1132231.01\n590263.08 ( — 48 %)\n100 (write)\n863745.10\n594401.43 ( — 32 %)\nWindows Server 2019:\nWrite (percent)\nодин CPU — IOPS\nдва CPU — IOPS\n0 (read)\n1026432.57\n818586.28 ( — 21%)\n100 (write)\n953902.69\n842953.92 ( — 12 %)\nВидно, что синхронизация работы CPU через UPI-линию существенно снизила результаты. Падение производительности с двумя CPU под Win2019 существенно меньше, чем под Win2016.\n### ▍ Вторая часть марлезонского балета:\nА теперь установим оба CPU. Но вся RAM будет на CPU1, а NVME — на CPU2.\nRAM подключена к CPU1, а NVME-диски — к CPU2.\nТесты на количество IOPS такие же, как в предыдущем разделе.\nТесты на пропускную способность:\nЧтение: DiskSpd64.exe -b128K -t32 -o32 -w0 -d10 -si -S -c100G F:/testfile.dat G:/testfile.dat\nЗапись: DiskSpd64.exe -b128K -t32 -o32 -w100 -d10 -si -S -c100G F:/testfile.dat G:/testfile.dat\nКоличество IOPS:\nWrite (Percent)\nWin2016 — IOPS — 4K\nWin2019 — IOPS — 4K block'}],
#    'doc_ids': '',
#    'answer': ''}}]

# %%
def traces_to_dataframe(traces: list) -> pd.DataFrame:
    """Преобразует список трейсов MLflow в DataFrame."""
    data = []
    for trace in traces:
        request_id = trace.get('request_id')
        inp = trace.get('input', {})
        out = trace.get('output', {})
        question = inp.get('query', '')
        answer = out.get('answer', '')
        
        # 3. Обработка документов
        documents = out.get('documents', [])
        
        if documents:
            # Если документов нет, добавляем запись только с вопросом и ответом
            data.append({
                'request_id': request_id,
                'question': question,
                'answer': answer,
                'document_id': [doc.get('document_id') for doc in documents],
                'chunk_id': [doc.get('chunk_id') for doc in documents],
                'content': [doc.get('content') for doc in documents]
            })
    df = pd.DataFrame(data)
    return df

# Создаем DataFrame
df = traces_to_dataframe(traces_content)
df
# Out:
#                             request_id  \
# 0  tr-b660fb9af941f0e1789c7d0e596cc36f
# 1  tr-b660fb9af941f0e1789c7d0e596cc36f
# 2  tr-71da94c6e7948a253982c5428825dae8
# 3  tr-71da94c6e7948a253982c5428825dae8
# 4  tr-b8854fdd3c08f65b6dde8f8bc508d352
# 5  tr-b8854fdd3c08f65b6dde8f8bc508d352
# 6  tr-b6b7066273722baa79262943f9d8a986
# 7  tr-b6b7066273722baa79262943f9d8a986
#
#                                                                                               question  \
# 0  Как создать кастомную тень для View, чтобы она имела произвольную форму, учитывая ограничения св...
# 1  Как создать кастомную тень для View, чтобы она имела произвольную форму, учитывая ограничения св...
# 2                       Какую новую форму оценки требуют абитуриенты Университета Чикаго с этой осени?
# 3                       Какую новую форму оценки требуют абитуриенты Университета Чикаго с этой осени?
# 4  Какие ограничения у свойства android:elevation при создании теней в Android, и как можно получит...
# 5  Какие ограничения у свойства android:elevation при создании теней в Android, и как можно получит...
# 6              Сколько презентаций PowerPoint, по оценкам Microsoft, демонстрируется в мире ежедневно?
# 7              Сколько презентаций PowerPoint, по оценкам Microsoft, демонстрируется в мире ежедневно?
#
#                                                                                                 answer  \
# 0  **Как создать пользовательскую тень произвольной формы для View**\n\n1. **Создайте графический р...
# 1  **Как создать пользовательскую тень произвольной формы для View**\n\n1. **Создайте графический р...
# 2  Новые требования к абитуриентам Университета Чикаго к началу осеннего семестра включают обязател...
# 3  Новые требования к абитуриентам Университета Чикаго к началу осеннего семестра включают обязател...
# 4
# 5
# 6  По оценкам Microsoft ежедневно в мире демонстрируется примерно **30 млн презентаций PowerPoint**...
# 7  По оценкам Microsoft ежедневно в мире демонстрируется примерно **30 млн презентаций PowerPoint**...
#
#    document_id  chunk_id  \
# 0            5         6
# 1            6         7
# 2            1         1
# 3            6        29
# 4            5         6
# 5            6         7
# 6            1         1
# 7            7        30
#
#                                                                                                content
# 0  REPEAT. Изображение повторяется горизонтально и вертикально. На изображении заметно, как темная ...
# 1  Кастомную тень можно создать и с помощью xml, прописав с градиентом:\n[code]\n \n[/code]\nМы пол...
# 2  Абитуриенты, поступающие в Университет Чикаго, уже начиная с этой осени, будут обязаны, помимо с...
# 3  Чтобы полностью исключить шину UPI из обработки и передачи данных, мы поступим самым простым и н...
# 4  REPEAT. Изображение повторяется горизонтально и вертикально. На изображении заметно, как темная ...
# 5  Кастомную тень можно создать и с помощью xml, прописав с градиентом:\n[code]\n \n[/code]\nМы пол...
# 6  Абитуриенты, поступающие в Университет Чикаго, уже начиная с этой осени, будут обязаны, помимо с...
# 7  Windows Server 2016:\nWrite (percent)\nодин CPU — IOPS\nдва CPU — IOPS\n0 (read)\n1132231.01\n59...
